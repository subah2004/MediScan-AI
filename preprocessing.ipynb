# %% [markdown]
# # AI-Driven X-ray Diagnosis & Report Generator
# ### Objective: Detect chest abnormalities in X-rays and auto-generate diagnostic reports.
# * Use EfficientNet or Vision Transformers (ViT) trained on ChestX-ray14 or MIMIC-CXR datasets.
# * Implement Grad-CAM++ or SHAP for visual explainability.
# * Integrate Gemini Pro / GPT-4V for radiology report generation using visual and prediction context

# %%
# %pip install tensorflow
# %pip install tensorflow_hub
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: tensorflow in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2023.5.7)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\subah\appdata\roaming\python\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tensorflow_hubNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow_hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow_hub) (4.25.3)
# Collecting tf-keras>=2.14.1 (from tensorflow_hub)
#   Downloading tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow<2.20,>=2.19 (from tf-keras>=2.14.1->tensorflow_hub)
#   Downloading tensorflow-2.19.0-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (23.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (70.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (1.64.1)
# Collecting tensorboard~=2.19.0 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.5.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.12.1)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub)
#   Downloading ml_dtypes-0.5.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.44.0)
# Requirement already satisfied: rich in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (13.7.1)
# Requirement already satisfied: namex in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.0.8)
# Requirement already satisfied: optree in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2023.5.7)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\subah\appdata\roaming\python\python311\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\subah\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow_hub) (0.1.2)
# Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Downloading tf_keras-2.19.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.2 MB/s eta 0:00:00
# Downloading tensorflow-2.19.0-cp311-cp311-win_amd64.whl (375.9 MB)
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 2.6/375.9 MB 11.6 MB/s eta 0:00:33
#    ---------------------------------------- 3.1/375.9 MB 12.3 MB/s eta 0:00:31
#    ---------------------------------------- 4.5/375.9 MB 6.9 MB/s eta 0:00:54
#     --------------------------------------- 7.3/375.9 MB 8.5 MB/s eta 0:00:44
#     --------------------------------------- 9.2/375.9 MB 8.8 MB/s eta 0:00:42
#    - -------------------------------------- 13.1/375.9 MB 10.4 MB/s eta 0:00:35
#    - -------------------------------------- 17.6/375.9 MB 11.9 MB/s eta 0:00:31
#    -- ------------------------------------- 21.0/375.9 MB 12.3 MB/s eta 0:00:29
#    -- ------------------------------------- 23.1/375.9 MB 12.0 MB/s eta 0:00:30
#    -- ------------------------------------- 26.2/375.9 MB 12.2 MB/s eta 0:00:29
#    --- ------------------------------------ 29.6/375.9 MB 12.5 MB/s eta 0:00:28
#    --- ------------------------------------ 32.5/375.9 MB 12.6 MB/s eta 0:00:28
#    --- ------------------------------------ 35.4/375.9 MB 12.6 MB/s eta 0:00:27
#    ---- ----------------------------------- 38.8/375.9 MB 13.0 MB/s eta 0:00:26
#    ---- ----------------------------------- 41.4/375.9 MB 12.8 MB/s eta 0:00:27
#    ---- ----------------------------------- 45.4/375.9 MB 13.1 MB/s eta 0:00:26
#    ----- ---------------------------------- 49.0/375.9 MB 13.3 MB/s eta 0:00:25
#    ----- ---------------------------------- 52.7/375.9 MB 13.6 MB/s eta 0:00:24
#    ----- ---------------------------------- 56.4/375.9 MB 13.8 MB/s eta 0:00:24
#    ------ --------------------------------- 60.6/375.9 MB 14.0 MB/s eta 0:00:23
#    ------ --------------------------------- 63.7/375.9 MB 14.1 MB/s eta 0:00:23
#    ------- -------------------------------- 67.9/375.9 MB 14.3 MB/s eta 0:00:22
#    ------- -------------------------------- 70.5/375.9 MB 14.6 MB/s eta 0:00:21
#    -------- ------------------------------- 77.1/375.9 MB 14.9 MB/s eta 0:00:20
#    -------- ------------------------------- 81.5/375.9 MB 15.2 MB/s eta 0:00:20
#    --------- ------------------------------ 86.0/375.9 MB 15.4 MB/s eta 0:00:19
#    --------- ------------------------------ 91.2/375.9 MB 15.7 MB/s eta 0:00:19
#    ---------- ----------------------------- 96.7/375.9 MB 16.1 MB/s eta 0:00:18
#    ---------- ---------------------------- 100.7/375.9 MB 16.2 MB/s eta 0:00:17
#    ---------- ---------------------------- 103.8/375.9 MB 16.2 MB/s eta 0:00:17
#    ----------- --------------------------- 107.0/375.9 MB 16.1 MB/s eta 0:00:17
#    ----------- --------------------------- 110.4/375.9 MB 16.1 MB/s eta 0:00:17
#    ----------- --------------------------- 114.8/375.9 MB 16.3 MB/s eta 0:00:17
#    ------------ -------------------------- 120.6/375.9 MB 16.6 MB/s eta 0:00:16
#    ------------ -------------------------- 123.2/375.9 MB 16.5 MB/s eta 0:00:16
#    ------------- ------------------------- 128.7/375.9 MB 16.7 MB/s eta 0:00:15
#    -------------- ------------------------ 135.0/375.9 MB 17.0 MB/s eta 0:00:15
#    -------------- ------------------------ 140.2/375.9 MB 17.2 MB/s eta 0:00:14
#    -------------- ------------------------ 144.2/375.9 MB 17.3 MB/s eta 0:00:14
#    --------------- ----------------------- 147.1/375.9 MB 17.1 MB/s eta 0:00:14
#    --------------- ----------------------- 149.9/375.9 MB 17.0 MB/s eta 0:00:14
#    --------------- ----------------------- 152.8/375.9 MB 17.0 MB/s eta 0:00:14
#    ---------------- ---------------------- 154.9/375.9 MB 16.9 MB/s eta 0:00:14
#    ---------------- ---------------------- 158.6/375.9 MB 16.9 MB/s eta 0:00:13
#    ---------------- ---------------------- 163.1/375.9 MB 16.9 MB/s eta 0:00:13
#    ----------------- --------------------- 168.3/375.9 MB 17.1 MB/s eta 0:00:13
#    ----------------- --------------------- 173.3/375.9 MB 17.2 MB/s eta 0:00:12
#    ------------------ -------------------- 178.5/375.9 MB 17.4 MB/s eta 0:00:12
#    ------------------ -------------------- 181.7/375.9 MB 17.4 MB/s eta 0:00:12
#    ------------------- ------------------- 184.5/375.9 MB 17.2 MB/s eta 0:00:12
#    ------------------- ------------------- 188.2/375.9 MB 17.3 MB/s eta 0:00:11
#    ------------------- ------------------- 191.4/375.9 MB 17.2 MB/s eta 0:00:11
#    -------------------- ------------------ 193.7/375.9 MB 17.1 MB/s eta 0:00:11
#    -------------------- ------------------ 197.1/375.9 MB 17.0 MB/s eta 0:00:11
#    -------------------- ------------------ 200.3/375.9 MB 17.0 MB/s eta 0:00:11
#    --------------------- ----------------- 203.9/375.9 MB 17.0 MB/s eta 0:00:11
#    --------------------- ----------------- 207.1/375.9 MB 16.9 MB/s eta 0:00:10
#    --------------------- ----------------- 211.3/375.9 MB 17.0 MB/s eta 0:00:10
#    ---------------------- ---------------- 215.0/375.9 MB 17.0 MB/s eta 0:00:10
#    ----------------------- --------------- 221.8/375.9 MB 17.2 MB/s eta 0:00:09
#    ----------------------- --------------- 227.3/375.9 MB 17.3 MB/s eta 0:00:09
#    ------------------------ -------------- 233.6/375.9 MB 17.5 MB/s eta 0:00:09
#    ------------------------ -------------- 238.8/375.9 MB 17.6 MB/s eta 0:00:08
#    ------------------------- ------------- 243.8/375.9 MB 17.7 MB/s eta 0:00:08
#    ------------------------- ------------- 247.7/375.9 MB 17.7 MB/s eta 0:00:08
#    -------------------------- ------------ 250.9/375.9 MB 17.7 MB/s eta 0:00:08
#    -------------------------- ------------ 254.3/375.9 MB 17.6 MB/s eta 0:00:07
#    -------------------------- ------------ 255.9/375.9 MB 17.6 MB/s eta 0:00:07
#    --------------------------- ----------- 260.3/375.9 MB 17.5 MB/s eta 0:00:07
#    --------------------------- ----------- 262.9/375.9 MB 17.5 MB/s eta 0:00:07
#    --------------------------- ----------- 266.9/375.9 MB 17.9 MB/s eta 0:00:07
#    ---------------------------- ---------- 272.4/375.9 MB 18.2 MB/s eta 0:00:06
#    ---------------------------- ---------- 277.9/375.9 MB 18.3 MB/s eta 0:00:06
#    ----------------------------- --------- 283.4/375.9 MB 18.4 MB/s eta 0:00:06
#    ----------------------------- --------- 284.2/375.9 MB 18.5 MB/s eta 0:00:05
#    ------------------------------ -------- 289.9/375.9 MB 18.6 MB/s eta 0:00:05
#    ------------------------------ -------- 294.9/375.9 MB 18.8 MB/s eta 0:00:05
#    ------------------------------- ------- 300.9/375.9 MB 19.1 MB/s eta 0:00:04
#    ------------------------------- ------- 307.5/375.9 MB 19.3 MB/s eta 0:00:04
#    -------------------------------- ------ 314.3/375.9 MB 19.6 MB/s eta 0:00:04
#    --------------------------------- ----- 318.5/375.9 MB 19.6 MB/s eta 0:00:03
#    --------------------------------- ----- 321.7/375.9 MB 19.5 MB/s eta 0:00:03
#    --------------------------------- ----- 324.8/375.9 MB 19.5 MB/s eta 0:00:03
#    ---------------------------------- ---- 328.2/375.9 MB 19.5 MB/s eta 0:00:03
#    ---------------------------------- ---- 330.3/375.9 MB 19.3 MB/s eta 0:00:03
#    ---------------------------------- ---- 332.9/375.9 MB 19.3 MB/s eta 0:00:03
#    ---------------------------------- ---- 335.5/375.9 MB 19.1 MB/s eta 0:00:03
#    ----------------------------------- --- 338.4/375.9 MB 18.9 MB/s eta 0:00:02
#    ----------------------------------- --- 342.6/375.9 MB 18.9 MB/s eta 0:00:02
#    ------------------------------------ -- 347.3/375.9 MB 19.0 MB/s eta 0:00:02
#    ------------------------------------ -- 352.1/375.9 MB 18.9 MB/s eta 0:00:02
#    ------------------------------------ -- 356.5/375.9 MB 18.8 MB/s eta 0:00:02
#    ------------------------------------- - 359.7/375.9 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- - 363.1/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  366.5/375.9 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  369.9/375.9 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  373.0/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------- 375.9/375.9 MB 15.9 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.1-cp311-cp311-win_amd64.whl (209 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    -------------------------------------- - 5.2/5.5 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 25.8 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes, tensorboard, tensorflow, tf-keras, tensorflow_hub
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
#   Rolling back uninstall of tensorflow
#   Moving to c:\users\subah\appdata\local\programs\python\python311\lib\site-packages\tensorflow-2.17.0.dist-info\
#    from C:\Users\subah\AppData\Local\Programs\Python\Python311\Lib\site-packages\~ensorflow-2.17.0.dist-info
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\subah\AppData\Local\Programs\Python\Python311\Lib\site-packages\~l_dtypes'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\subah\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\tensorflow\\compiler\\tf2tensorrt\\_pywrap_py_utils.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import os

# %%
# Define the root directory where images are stored
image_root_dir = r"C:\Users\subah\Downloads\XRAYIMAGES"

# Load the CSV file
data = pd.read_csv('Data_Entry_2017.csv')

# Remove invalid ages
data = data[data['Patient Age'] < 100] 

# Collect image paths from both "images1" and "images2"
data_image_paths = {os.path.basename(x): x for x in 
                    glob(os.path.join(image_root_dir, 'images*', '*.png'))}

# Print number of images found
print('Scans found:', len(data_image_paths), ', Total Headers:', data.shape[0])

# Map the image paths to the dataframe
data['path'] = data['Image Index'].map(data_image_paths.get)

# Convert age to integer
data['Patient Age'] = data['Patient Age'].astype(int)

# Print sample rows
data.sample(3)
# Out:
# Scans found: 25066 , Total Headers: 112104
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 23645   00006260_006.png     No Finding            6        6260           60
# 78000   00019150_018.png     No Finding           18       19150           67
# 106822  00028832_000.png     No Finding            0       28832           27
#
#        Patient Gender View Position  OriginalImage[Width  Height]  \
# 23645               M            AP                 3056     2544
# 78000               M            PA                 2992     2991
# 106822              M            PA                 2021     2021
#
#         OriginalImagePixelSpacing[x        y]  Unnamed: 11  \
# 23645                      0.139000  0.139000          NaN
# 78000                      0.143000  0.143000          NaN
# 106822                     0.194311  0.194311          NaN
#
#                                                      path
# 23645   C:\Users\subah\Downloads\XRAYIMAGES\images03\0...
# 78000                                                None
# 106822                                               None

# %% [markdown]
# Total number of x ray diseases per images

# %%
data['Finding Labels'].value_counts()
# Out:
# Finding Labels
# No Finding                                                         60353
# Infiltration                                                        9546
# Atelectasis                                                         4214
# Effusion                                                            3955
# Nodule                                                              2705
#                                                                    ...
# Atelectasis|Consolidation|Edema|Effusion|Infiltration|Pneumonia        1
# Atelectasis|Consolidation|Effusion|Emphysema|Mass|Pneumothorax         1
# Cardiomegaly|Effusion|Pleural_Thickening|Pneumothorax                  1
# Edema|Infiltration|Pneumothorax                                        1
# Atelectasis|Consolidation|Mass|Pleural_Thickening|Pneumothorax         1
# Name: count, Length: 836, dtype: int64

# %%
found_files_data = data[data['path'].notnull()]
found_files_data['Finding Labels'].value_counts()
# Out:
# Finding Labels
# No Finding                                                    14405
# Infiltration                                                   1663
# Atelectasis                                                    1014
# Effusion                                                        837
# Nodule                                                          664
#                                                               ...
# Effusion|Fibrosis|Nodule|Pleural_Thickening                       1
# Edema|Effusion|Infiltration|Pleural_Thickening                    1
# Consolidation|Infiltration|Pleural_Thickening|Pneumothorax        1
# Effusion|Pleural_Thickening|Pneumonia                             1
# Cardiomegaly|Infiltration|Nodule                                  1
# Name: count, Length: 404, dtype: int64

# %%
# Total number of images 
found_files_data['Finding Labels'].value_counts().sum()
# Out:
# 25065

# %%
data = data[data['Finding Labels'] != 'No Finding']

# %%
found_files_data1 = data[data['path'].notnull()]
found_files_data1['Finding Labels'].value_counts()
# Out:
# Finding Labels
# Infiltration                                                  1663
# Atelectasis                                                   1014
# Effusion                                                       837
# Nodule                                                         664
# Mass                                                           458
#                                                               ...
# Effusion|Fibrosis|Nodule|Pleural_Thickening                      1
# Edema|Effusion|Infiltration|Pleural_Thickening                   1
# Consolidation|Infiltration|Pleural_Thickening|Pneumothorax       1
# Effusion|Pleural_Thickening|Pneumonia                            1
# Cardiomegaly|Infiltration|Nodule                                 1
# Name: count, Length: 403, dtype: int64

# %%
found_files_data1['Finding Labels'].value_counts().sum()
# Out:
# 10660

# %%
found_files_data1.head(10)
# Out:
#          Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0   00000001_000.png            Cardiomegaly            0           1
# 1   00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2   00000001_002.png   Cardiomegaly|Effusion            2           1
# 4   00000003_000.png                  Hernia            0           3
# 5   00000003_001.png                  Hernia            1           3
# 6   00000003_002.png                  Hernia            2           3
# 7   00000003_003.png     Hernia|Infiltration            3           3
# 8   00000003_004.png                  Hernia            4           3
# 9   00000003_005.png                  Hernia            5           3
# 10  00000003_006.png                  Hernia            6           3
#
#     Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0            58              M            PA                 2682     2749
# 1            58              M            PA                 2894     2729
# 2            58              M            PA                 2500     2048
# 4            81              F            PA                 2582     2991
# 5            74              F            PA                 2500     2048
# 6            75              F            PA                 2048     2500
# 7            76              F            PA                 2698     2991
# 8            77              F            PA                 2500     2048
# 9            78              F            PA                 2686     2991
# 10           79              F            PA                 2992     2991
#
#     OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 0                         0.143  0.143          NaN
# 1                         0.143  0.143          NaN
# 2                         0.168  0.168          NaN
# 4                         0.143  0.143          NaN
# 5                         0.168  0.168          NaN
# 6                         0.168  0.168          NaN
# 7                         0.143  0.143          NaN
# 8                         0.168  0.168          NaN
# 9                         0.143  0.143          NaN
# 10                        0.143  0.143          NaN
#
#                                                  path
# 0   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 1   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 2   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 4   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 5   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 6   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 7   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 8   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 9   C:\Users\subah\Downloads\XRAYIMAGES\images01\0...
# 10  C:\Users\subah\Downloads\XRAYIMAGES\images01\0...

# %%
found_files_data1['Finding Labels'].unique()
# Out:
# array(['Cardiomegaly', 'Cardiomegaly|Emphysema', 'Cardiomegaly|Effusion',
#        'Hernia', 'Hernia|Infiltration', 'Mass|Nodule', 'Infiltration',
#        'Effusion|Infiltration', 'Nodule', 'Emphysema', 'Effusion',
#        'Atelectasis', 'Effusion|Mass', 'Emphysema|Pneumothorax',
#        'Pleural_Thickening',
#        'Effusion|Emphysema|Infiltration|Pneumothorax',
#        'Emphysema|Infiltration|Pleural_Thickening|Pneumothorax',
#        'Effusion|Pneumonia|Pneumothorax', 'Pneumothorax',
#        'Effusion|Infiltration|Pneumothorax', 'Infiltration|Mass',
#        'Infiltration|Mass|Pneumothorax', 'Mass',
#        'Cardiomegaly|Infiltration|Mass|Nodule',
#        'Cardiomegaly|Effusion|Emphysema|Mass',
#        'Atelectasis|Cardiomegaly|Emphysema|Mass|Pneumothorax',
#        'Emphysema|Mass', 'Emphysema|Mass|Pneumothorax',
#        'Atelectasis|Pneumothorax', 'Cardiomegaly|Emphysema|Pneumothorax',
#        'Mass|Pleural_Thickening', 'Cardiomegaly|Mass|Pleural_Thickening',
#        'Effusion|Infiltration|Nodule',
#        'Atelectasis|Effusion|Pleural_Thickening', 'Fibrosis|Infiltration',
#        'Fibrosis|Infiltration|Pleural_Thickening', 'Fibrosis',
#        'Infiltration|Mass|Nodule', 'Cardiomegaly|Edema|Effusion',
#        'Atelectasis|Effusion|Infiltration',
#        'Atelectasis|Consolidation|Edema|Pneumonia', 'Consolidation',
#        'Edema|Infiltration', 'Edema', 'Cardiomegaly|Consolidation',
#        'Cardiomegaly|Infiltration',
#        'Cardiomegaly|Edema|Effusion|Infiltration',
#        'Atelectasis|Edema|Effusion|Infiltration',
#        'Cardiomegaly|Edema|Infiltration', 'Consolidation|Infiltration',
#        'Consolidation|Edema', 'Cardiomegaly|Edema',
#        'Edema|Effusion|Infiltration|Nodule',
#        'Atelectasis|Edema|Infiltration', 'Edema|Effusion|Infiltration',
#        'Atelectasis|Cardiomegaly|Fibrosis', 'Atelectasis|Infiltration',
#        'Consolidation|Mass', 'Emphysema|Infiltration',
#        'Consolidation|Effusion|Infiltration',
#        'Infiltration|Pleural_Thickening', 'Atelectasis|Effusion',
#        'Fibrosis|Infiltration|Nodule', 'Nodule|Pneumonia',
#        'Infiltration|Nodule', 'Effusion|Pleural_Thickening',
#        'Edema|Effusion|Infiltration|Pleural_Thickening|Pneumonia',
#        'Effusion|Fibrosis', 'Pneumonia', 'Edema|Effusion',
#        'Consolidation|Effusion|Infiltration|Mass',
#        'Consolidation|Effusion|Infiltration|Nodule',
#        'Effusion|Emphysema|Infiltration',
#        'Atelectasis|Cardiomegaly|Consolidation|Effusion',
#        'Consolidation|Effusion', 'Atelectasis|Consolidation',
#        'Mass|Pneumothorax', 'Atelectasis|Mass',
#        'Atelectasis|Effusion|Mass', 'Atelectasis|Cardiomegaly|Effusion',
#        'Effusion|Pneumothorax',
#        'Cardiomegaly|Effusion|Pleural_Thickening',
#        'Atelectasis|Emphysema', 'Atelectasis|Emphysema|Pneumothorax',
#        'Cardiomegaly|Nodule', 'Consolidation|Pleural_Thickening',
#        'Effusion|Fibrosis|Nodule|Pleural_Thickening',
#        'Effusion|Fibrosis|Mass|Nodule|Pleural_Thickening',
#        'Effusion|Nodule', 'Atelectasis|Fibrosis',
#        'Effusion|Nodule|Pleural_Thickening',
#        'Atelectasis|Infiltration|Pneumonia',
#        'Atelectasis|Infiltration|Pleural_Thickening',
#        'Consolidation|Infiltration|Mass', 'Fibrosis|Nodule',
#        'Nodule|Pleural_Thickening',
#        'Cardiomegaly|Edema|Effusion|Fibrosis|Infiltration',
#        'Cardiomegaly|Consolidation|Edema|Effusion',
#        'Atelectasis|Cardiomegaly|Effusion|Infiltration',
#        'Cardiomegaly|Edema|Effusion|Infiltration|Pneumonia',
#        'Cardiomegaly|Effusion|Pneumonia',
#        'Atelectasis|Cardiomegaly|Infiltration|Pneumothorax',
#        'Fibrosis|Pleural_Thickening', 'Cardiomegaly|Effusion|Mass',
#        'Cardiomegaly|Effusion|Infiltration', 'Infiltration|Pneumonia',
#        'Infiltration|Pneumothorax',
#        'Infiltration|Nodule|Pleural_Thickening',
#        'Effusion|Fibrosis|Infiltration',
#        'Fibrosis|Nodule|Pleural_Thickening', 'Consolidation|Pneumothorax',
#        'Atelectasis|Infiltration|Mass',
#        'Atelectasis|Infiltration|Mass|Pleural_Thickening',
#        'Effusion|Infiltration|Mass', 'Atelectasis|Nodule',
#        'Consolidation|Infiltration|Nodule', 'Fibrosis|Mass',
#        'Cardiomegaly|Hernia', 'Cardiomegaly|Effusion|Hernia',
#        'Atelectasis|Effusion|Pneumothorax',
#        'Infiltration|Pleural_Thickening|Pneumothorax',
#        'Consolidation|Infiltration|Mass|Pleural_Thickening',
#        'Atelectasis|Effusion|Emphysema|Pleural_Thickening',
#        'Atelectasis|Edema|Mass', 'Cardiomegaly|Fibrosis',
#        'Consolidation|Fibrosis|Infiltration|Nodule',
#        'Effusion|Emphysema|Pleural_Thickening',
#        'Atelectasis|Consolidation|Effusion|Mass|Pleural_Thickening',
#        'Fibrosis|Infiltration|Nodule|Pneumonia',
#        'Cardiomegaly|Edema|Infiltration|Nodule',
#        'Atelectasis|Cardiomegaly', 'Edema|Infiltration|Pneumonia',
#        'Edema|Infiltration|Nodule',
#        'Cardiomegaly|Infiltration|Nodule|Pneumonia',
#        'Infiltration|Pneumonia|Pneumothorax',
#        'Atelectasis|Pleural_Thickening',
#        'Consolidation|Edema|Effusion|Pneumothorax',
#        'Atelectasis|Effusion|Infiltration|Nodule',
#        'Edema|Effusion|Pneumonia',
#        'Edema|Effusion|Infiltration|Pneumonia',
#        'Edema|Infiltration|Pleural_Thickening', 'Consolidation|Fibrosis',
#        'Effusion|Infiltration|Pleural_Thickening',
#        'Fibrosis|Infiltration|Pneumonia',
#        'Consolidation|Mass|Nodule|Pneumothorax',
#        'Cardiomegaly|Pleural_Thickening', 'Hernia|Mass',
#        'Effusion|Infiltration|Pleural_Thickening|Pneumonia',
#        'Atelectasis|Nodule|Pleural_Thickening',
#        'Atelectasis|Effusion|Infiltration|Pleural_Thickening',
#        'Atelectasis|Infiltration|Pneumothorax', 'Nodule|Pneumothorax',
#        'Atelectasis|Consolidation|Infiltration', 'Atelectasis|Pneumonia',
#        'Atelectasis|Infiltration|Nodule', 'Emphysema|Infiltration|Nodule',
#        'Fibrosis|Pneumonia', 'Effusion|Emphysema',
#        'Atelectasis|Consolidation|Effusion|Infiltration',
#        'Cardiomegaly|Effusion|Fibrosis|Pleural_Thickening|Pneumothorax',
#        'Consolidation|Infiltration|Pneumothorax',
#        'Effusion|Mass|Pneumothorax', 'Pleural_Thickening|Pneumonia',
#        'Edema|Effusion|Nodule|Pneumonia', 'Effusion|Pneumonia',
#        'Effusion|Infiltration|Nodule|Pleural_Thickening',
#        'Consolidation|Fibrosis|Nodule',
#        'Consolidation|Nodule|Pleural_Thickening',
#        'Cardiomegaly|Infiltration|Pneumothorax',
#        'Consolidation|Effusion|Nodule', 'Effusion|Infiltration|Pneumonia',
#        'Atelectasis|Consolidation|Effusion', 'Emphysema|Fibrosis',
#        'Effusion|Emphysema|Fibrosis|Mass|Nodule', 'Fibrosis|Hernia',
#        'Atelectasis|Emphysema|Infiltration|Pneumonia',
#        'Consolidation|Mass|Nodule',
#        'Atelectasis|Edema|Pleural_Thickening', 'Atelectasis|Edema',
#        'Atelectasis|Consolidation|Pneumothorax',
#        'Consolidation|Effusion|Mass', 'Atelectasis|Effusion|Emphysema',
#        'Atelectasis|Infiltration|Nodule|Pleural_Thickening',
#        'Infiltration|Nodule|Pneumothorax',
#        'Atelectasis|Consolidation|Fibrosis|Nodule',
#        'Consolidation|Infiltration|Pleural_Thickening',
#        'Fibrosis|Infiltration|Mass|Pleural_Thickening',
#        'Cardiomegaly|Mass', 'Edema|Fibrosis',
#        'Atelectasis|Consolidation|Edema', 'Emphysema|Pleural_Thickening',
#        'Pleural_Thickening|Pneumothorax',
#        'Effusion|Pleural_Thickening|Pneumothorax',
#        'Effusion|Fibrosis|Pneumonia', 'Consolidation|Effusion|Pneumonia',
#        'Emphysema|Mass|Nodule|Pneumothorax',
#        'Emphysema|Nodule|Pneumothorax',
#        'Atelectasis|Effusion|Infiltration|Pneumothorax',
#        'Edema|Pleural_Thickening',
#        'Emphysema|Infiltration|Pleural_Thickening',
#        'Atelectasis|Emphysema|Infiltration',
#        'Atelectasis|Effusion|Infiltration|Mass',
#        'Atelectasis|Consolidation|Mass', 'Consolidation|Nodule',
#        'Consolidation|Effusion|Pleural_Thickening',
#        'Atelectasis|Cardiomegaly|Edema|Effusion|Infiltration|Pneumothorax',
#        'Atelectasis|Cardiomegaly|Effusion|Mass',
#        'Atelectasis|Cardiomegaly|Consolidation|Effusion|Mass',
#        'Atelectasis|Pleural_Thickening|Pneumothorax',
#        'Atelectasis|Emphysema|Pleural_Thickening|Pneumothorax',
#        'Emphysema|Pleural_Thickening|Pneumothorax',
#        'Atelectasis|Cardiomegaly|Infiltration',
#        'Cardiomegaly|Consolidation|Infiltration',
#        'Atelectasis|Cardiomegaly|Effusion|Infiltration|Nodule',
#        'Cardiomegaly|Edema|Pleural_Thickening',
#        'Cardiomegaly|Effusion|Fibrosis|Nodule',
#        'Cardiomegaly|Infiltration|Pleural_Thickening',
#        'Atelectasis|Effusion|Emphysema|Pneumothorax',
#        'Effusion|Mass|Nodule|Pleural_Thickening',
#        'Atelectasis|Effusion|Nodule',
#        'Atelectasis|Cardiomegaly|Consolidation|Infiltration',
#        'Atelectasis|Cardiomegaly|Effusion|Fibrosis',
#        'Consolidation|Mass|Pleural_Thickening',
#        'Atelectasis|Edema|Effusion|Pneumonia|Pneumothorax',
#        'Atelectasis|Effusion|Infiltration|Pneumonia',
#        'Mass|Nodule|Pneumonia',
#        'Consolidation|Effusion|Infiltration|Mass|Nodule',
#        'Atelectasis|Fibrosis|Nodule',
#        'Cardiomegaly|Edema|Effusion|Pneumonia', 'Edema|Pneumonia',
#        'Cardiomegaly|Edema|Infiltration|Pneumonia',
#        'Atelectasis|Cardiomegaly|Edema|Infiltration',
#        'Cardiomegaly|Fibrosis|Infiltration',
#        'Consolidation|Emphysema|Pleural_Thickening',
#        'Cardiomegaly|Effusion|Fibrosis',
#        'Atelectasis|Cardiomegaly|Effusion|Fibrosis|Infiltration',
#        'Cardiomegaly|Effusion|Fibrosis|Infiltration|Pleural_Thickening',
#        'Atelectasis|Consolidation|Edema|Infiltration|Pneumonia',
#        'Atelectasis|Consolidation|Infiltration|Pneumonia',
#        'Atelectasis|Consolidation|Effusion|Infiltration|Nodule',
#        'Atelectasis|Consolidation|Mass|Nodule',
#        'Atelectasis|Emphysema|Infiltration|Pleural_Thickening',
#        'Mass|Pneumonia', 'Cardiomegaly|Pneumonia',
#        'Atelectasis|Effusion|Infiltration|Mass|Pneumothorax',
#        'Atelectasis|Emphysema|Mass|Pneumothorax',
#        'Effusion|Emphysema|Pneumothorax',
#        'Atelectasis|Consolidation|Effusion|Infiltration|Mass|Nodule',
#        'Edema|Effusion|Infiltration|Pleural_Thickening',
#        'Consolidation|Infiltration|Pleural_Thickening|Pneumothorax',
#        'Effusion|Pleural_Thickening|Pneumonia',
#        'Consolidation|Effusion|Pneumothorax', 'Edema|Mass',
#        'Emphysema|Fibrosis|Hernia|Infiltration|Pleural_Thickening',
#        'Atelectasis|Cardiomegaly|Effusion|Pleural_Thickening',
#        'Effusion|Fibrosis|Infiltration|Pleural_Thickening',
#        'Effusion|Fibrosis|Pleural_Thickening',
#        'Consolidation|Pneumonia|Pneumothorax',
#        'Consolidation|Edema|Pneumothorax',
#        'Consolidation|Infiltration|Pleural_Thickening|Pneumonia',
#        'Atelectasis|Effusion|Fibrosis',
#        'Atelectasis|Consolidation|Effusion|Fibrosis',
#        'Atelectasis|Consolidation|Effusion|Mass',
#        'Atelectasis|Consolidation|Effusion|Pleural_Thickening',
#        'Cardiomegaly|Effusion|Infiltration|Pneumothorax',
#        'Cardiomegaly|Fibrosis|Nodule', 'Effusion|Mass|Pleural_Thickening',
#        'Atelectasis|Edema|Infiltration|Nodule', 'Edema|Infiltration|Mass',
#        'Consolidation|Emphysema', 'Emphysema|Pneumonia',
#        'Atelectasis|Cardiomegaly|Pneumonia',
#        'Atelectasis|Cardiomegaly|Edema',
#        'Atelectasis|Emphysema|Infiltration|Mass',
#        'Consolidation|Effusion|Infiltration|Pleural_Thickening',
#        'Cardiomegaly|Effusion|Emphysema',
#        'Edema|Infiltration|Mass|Nodule|Pleural_Thickening',
#        'Atelectasis|Edema|Infiltration|Pleural_Thickening',
#        'Edema|Nodule', 'Atelectasis|Fibrosis|Infiltration',
#        'Edema|Mass|Pneumonia', 'Effusion|Fibrosis|Mass',
#        'Consolidation|Pneumonia',
#        'Consolidation|Fibrosis|Pleural_Thickening',
#        'Effusion|Emphysema|Nodule', 'Atelectasis|Fibrosis|Mass',
#        'Atelectasis|Nodule|Pneumothorax', 'Mass|Nodule|Pneumothorax',
#        'Atelectasis|Consolidation|Emphysema', 'Effusion|Mass|Nodule',
#        'Cardiomegaly|Infiltration|Nodule|Mass',
#        'Atelectasis|Effusion|Pneumonia', 'Atelectasis|Edema|Effusion',
#        'Consolidation|Effusion|Emphysema|Pneumothorax',
#        'Infiltration|Mass|Pneumonia',
#        'Emphysema|Infiltration|Pneumothorax',
#        'Atelectasis|Emphysema|Nodule|Pneumothorax',
#        'Cardiomegaly|Pneumothorax', 'Edema|Effusion|Mass',
#        'Consolidation|Infiltration|Nodule|Pneumothorax',
#        'Cardiomegaly|Consolidation|Emphysema|Pneumothorax',
#        'Cardiomegaly|Consolidation|Effusion',
#        'Atelectasis|Effusion|Mass|Nodule',
#        'Edema|Infiltration|Mass|Pneumonia',
#        'Cardiomegaly|Consolidation|Effusion|Mass|Nodule',
#        'Atelectasis|Cardiomegaly|Effusion|Fibrosis|Nodule',
#        'Atelectasis|Effusion|Emphysema|Infiltration',
#        'Atelectasis|Edema|Emphysema|Nodule',
#        'Fibrosis|Pleural_Thickening|Pneumothorax',
#        'Fibrosis|Pneumothorax', 'Atelectasis|Effusion|Mass|Pneumothorax',
#        'Pneumothorax|Pneumonia', 'Atelectasis|Infiltration|Mass|Nodule',
#        'Atelectasis|Infiltration|Nodule|Pneumothorax',
#        'Emphysema|Infiltration|Mass',
#        'Atelectasis|Emphysema|Pleural_Thickening',
#        'Fibrosis|Infiltration|Pneumothorax', 'Edema|Effusion|Nodule',
#        'Consolidation|Fibrosis|Infiltration',
#        'Cardiomegaly|Consolidation|Edema|Infiltration',
#        'Effusion|Infiltration|Mass|Nodule',
#        'Cardiomegaly|Effusion|Nodule', 'Hernia|Nodule',
#        'Consolidation|Edema|Effusion', 'Fibrosis|Mass|Pleural_Thickening',
#        'Edema|Emphysema|Pneumothorax',
#        'Atelectasis|Consolidation|Emphysema|Infiltration|Pneumothorax',
#        'Cardiomegaly|Effusion|Infiltration|Pleural_Thickening',
#        'Consolidation|Edema|Infiltration', 'Effusion|Emphysema|Mass',
#        'Atelectasis|Cardiomegaly|Pleural_Thickening',
#        'Mass|Nodule|Pleural_Thickening',
#        'Emphysema|Infiltration|Nodule|Pneumothorax', 'Atelectasis|Hernia',
#        'Atelectasis|Hernia|Infiltration', 'Hernia|Infiltration|Mass',
#        'Atelectasis|Emphysema|Infiltration|Nodule|Pneumothorax',
#        'Cardiomegaly|Mass|Nodule', 'Emphysema|Fibrosis|Infiltration',
#        'Atelectasis|Consolidation|Pleural_Thickening',
#        'Consolidation|Emphysema|Infiltration', 'Fibrosis|Mass|Nodule',
#        'Edema|Effusion|Fibrosis|Infiltration|Mass',
#        'Mass|Pleural_Thickening|Pneumothorax',
#        'Consolidation|Fibrosis|Mass|Pleural_Thickening',
#        'Atelectasis|Mass|Nodule',
#        'Cardiomegaly|Effusion|Fibrosis|Infiltration',
#        'Cardiomegaly|Effusion|Infiltration|Nodule',
#        'Emphysema|Mass|Nodule',
#        'Emphysema|Infiltration|Mass|Pneumothorax',
#        'Effusion|Mass|Pleural_Thickening|Pneumothorax',
#        'Effusion|Infiltration|Mass|Pleural_Thickening',
#        'Atelectasis|Consolidation|Pneumonia',
#        'Cardiomegaly|Edema|Effusion|Infiltration|Nodule',
#        'Emphysema|Nodule',
#        'Atelectasis|Effusion|Infiltration|Mass|Nodule|Pleural_Thickening',
#        'Atelectasis|Hernia|Mass', 'Atelectasis|Edema|Nodule',
#        'Atelectasis|Cardiomegaly|Consolidation',
#        'Atelectasis|Consolidation|Effusion|Fibrosis|Nodule',
#        'Edema|Infiltration|Pleural_Thickening|Pneumonia',
#        'Atelectasis|Mass|Pleural_Thickening',
#        'Effusion|Infiltration|Mass|Pneumothorax',
#        'Effusion|Fibrosis|Infiltration|Pleural_Thickening|Pneumonia',
#        'Emphysema|Fibrosis|Pneumothorax',
#        'Consolidation|Fibrosis|Pneumothorax',
#        'Atelectasis|Consolidation|Effusion|Infiltration|Pleural_Thickening|Pneumothorax',
#        'Effusion|Fibrosis|Pneumothorax',
#        'Atelectasis|Consolidation|Effusion|Infiltration|Pneumothorax',
#        'Atelectasis|Consolidation|Effusion|Nodule',
#        'Consolidation|Mass|Pneumothorax',
#        'Effusion|Mass|Nodule|Pneumothorax',
#        'Atelectasis|Effusion|Mass|Pleural_Thickening',
#        'Infiltration|Mass|Nodule|Pneumothorax',
#        'Atelectasis|Consolidation|Edema|Effusion',
#        'Effusion|Fibrosis|Infiltration|Mass',
#        'Atelectasis|Emphysema|Fibrosis|Mass|Pneumothorax',
#        'Cardiomegaly|Infiltration|Mass',
#        'Infiltration|Mass|Pleural_Thickening', 'Edema|Emphysema',
#        'Fibrosis|Hernia|Mass', 'Consolidation|Edema|Infiltration|Nodule',
#        'Atelectasis|Consolidation|Mass|Pneumonia',
#        'Atelectasis|Mass|Pneumonia',
#        'Atelectasis|Consolidation|Mass|Pneumothorax',
#        'Atelectasis|Consolidation|Nodule',
#        'Emphysema|Hernia|Pleural_Thickening',
#        'Atelectasis|Consolidation|Effusion|Mass|Nodule',
#        'Emphysema|Hernia',
#        'Atelectasis|Effusion|Infiltration|Mass|Nodule',
#        'Atelectasis|Consolidation|Edema|Pneumonia|Pneumothorax',
#        'Atelectasis|Cardiomegaly|Effusion|Infiltration|Mass',
#        'Consolidation|Hernia',
#        'Atelectasis|Effusion|Fibrosis|Infiltration',
#        'Atelectasis|Consolidation|Effusion|Infiltration|Mass',
#        'Atelectasis|Infiltration|Pleural_Thickening|Pneumothorax',
#        'Atelectasis|Effusion|Nodule|Pneumothorax',
#        'Fibrosis|Mass|Nodule|Pleural_Thickening',
#        'Atelectasis|Fibrosis|Hernia',
#        'Edema|Effusion|Emphysema|Infiltration',
#        'Cardiomegaly|Consolidation|Nodule',
#        'Infiltration|Mass|Nodule|Pleural_Thickening',
#        'Cardiomegaly|Infiltration|Nodule'], dtype=object)

# %% [markdown]
# Since we have a mix diseases in the same image we are going to explode the `Finding Labels` coloumn as rows. This way the model we are about to train would not be confused.

# %%
# Filling the null values with blank string and splitting the labels into a list
# This is important for the next step where we will be using the labels for training
print("Before: ",found_files_data1['Finding Labels'].isna().sum())  # Count NaN values
found_files_data1['Finding Labels'] = found_files_data1['Finding Labels'].fillna("")
# Out:
# Before:  0

# %%
print("After: ",found_files_data1['Finding Labels'].isna().sum())
# Out:
# After:  0

# %%
found_files_data1['Finding Labels'] = found_files_data1['Finding Labels'].astype(str).str.split("|")

# %%
df = found_files_data1.explode('Finding Labels')
df['Finding Labels'].unique()
# Out:
# array(['Cardiomegaly', 'Emphysema', 'Effusion', 'Hernia', 'Infiltration',
#        'Mass', 'Nodule', 'Atelectasis', 'Pneumothorax',
#        'Pleural_Thickening', 'Pneumonia', 'Fibrosis', 'Edema',
#        'Consolidation'], dtype=object)

# %% [markdown]
# Dataset is imbalanced. It wouldn't be good for long run as the model can be baised towards majority class so we can perform data augmentation.

# %%
df['Finding Labels'].value_counts()
# Out:
# Finding Labels
# Infiltration          3625
# Effusion              2476
# Atelectasis           2461
# Nodule                1351
# Mass                  1024
# Pneumothorax           935
# Consolidation          889
# Cardiomegaly           795
# Pleural_Thickening     715
# Emphysema              533
# Fibrosis               514
# Edema                  391
# Pneumonia              266
# Hernia                  68
# Name: count, dtype: int64
